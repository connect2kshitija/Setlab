# %% [markdown]
# 1.	Implement linear regression problem using Google colab (Perform preprocessing, training and testing)

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
energy = pd.read_csv('/energydata_complete.csv')

# %%
energy.shape
# Out:
# (19735, 29)

# %%
energy.head()
# Out:
#                   date  Appliances  lights  ...  Tdewpoint        rv1        rv2
# 0  2016-01-11 17:00:00          60      30  ...        5.3  13.275433  13.275433
# 1  2016-01-11 17:10:00          60      30  ...        5.2  18.606195  18.606195
# 2  2016-01-11 17:20:00          50      30  ...        5.1  28.642668  28.642668
# 3  2016-01-11 17:30:00          50      40  ...        5.0  45.410389  45.410389
# 4  2016-01-11 17:40:00          60      40  ...        4.9  10.084097  10.084097
#
# [5 rows x 29 columns]

# %%
energy.plot("Tdewpoint", "rv2")

# %%
energy.plot.scatter("Tdewpoint", "rv2")

# %%
x_train, x_test, y_train, y_test = train_test_split(energy.Tdewpoint, energy.rv2 , test_size = 0.2)

# %%
regr = LinearRegression()

# %%
regr.fit(np.array(x_train).reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
preds = regr.predict(np.array(x_test).reshape(-1,1))

# %%
y_test.head()
# Out:
# 14867     2.235348
# 1103      6.144556
# 2008     26.383133
# 7311     48.284724
# 10441    48.064108
# Name: rv2, dtype: float64

# %%
preds
# Out:
# array([25.16314416, 25.27490969, 25.04421418, ..., 24.95340469,
#        25.05997599, 25.13412811])

# %%
residuals = preds - y_test

# %%
plt.hist(residuals)
# Out:
# (array([380., 379., 413., 360., 396., 389., 399., 438., 368., 425.]),
#  array([-25.0343059 , -20.01644534, -14.99858479,  -9.98072424,
#          -4.96286368,   0.05499687,   5.07285742,  10.09071797,
#          15.10857853,  20.12643908,  25.14429963]),
#  <a list of 10 Patch objects>)

# %%
mean_squared_error(y_test, preds) ** 0.5
# Out:
# 14.477070099481871
